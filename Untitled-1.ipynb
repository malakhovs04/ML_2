# %%
import pandas as pd
import numpy as np
import seaborn as sns
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.tree import export_text
from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('CreditScoring.csv')
df
# Out:
#       Status  Seniority  Home  Time  Age  Marital  Records  Job  Expenses  \
# 0          1          9     1    60   30        2        1    3        73
# 1          1         17     1    60   58        3        1    1        48
# 2          2         10     2    36   46        2        2    3        90
# 3          1          0     1    60   24        1        1    1        63
# 4          1          0     1    36   26        1        1    1        46
# ...      ...        ...   ...   ...  ...      ...      ...  ...       ...
# 4450       2          1     1    60   39        2        1    1        69
# 4451       1         22     2    60   46        2        1    1        60
# 4452       2          0     2    24   37        2        1    2        60
# 4453       1          0     1    48   23        1        1    3        49
# 4454       1          5     2    60   32        2        1    3        60
#
#       Income  Assets  Debt  Amount  Price
# 0        129       0     0     800    846
# 1        131       0     0    1000   1658
# 2        200    3000     0    2000   2985
# 3        182    2500     0     900   1325
# 4        107       0     0     310    910
# ...      ...     ...   ...     ...    ...
# 4450      92       0     0     900   1020
# 4451      75    3000   600     950   1263
# 4452      90    3500     0     500    963
# 4453     140       0     0     550    550
# 4454     140    4000  1000    1350   1650
#
# [4455 rows x 14 columns]

# %%
df.columns = df.columns.str.lower()
df
# Out:
#       status  seniority  home  time  age  marital  records  job  expenses  \
# 0          1          9     1    60   30        2        1    3        73
# 1          1         17     1    60   58        3        1    1        48
# 2          2         10     2    36   46        2        2    3        90
# 3          1          0     1    60   24        1        1    1        63
# 4          1          0     1    36   26        1        1    1        46
# ...      ...        ...   ...   ...  ...      ...      ...  ...       ...
# 4450       2          1     1    60   39        2        1    1        69
# 4451       1         22     2    60   46        2        1    1        60
# 4452       2          0     2    24   37        2        1    2        60
# 4453       1          0     1    48   23        1        1    3        49
# 4454       1          5     2    60   32        2        1    3        60
#
#       income  assets  debt  amount  price
# 0        129       0     0     800    846
# 1        131       0     0    1000   1658
# 2        200    3000     0    2000   2985
# 3        182    2500     0     900   1325
# 4        107       0     0     310    910
# ...      ...     ...   ...     ...    ...
# 4450      92       0     0     900   1020
# 4451      75    3000   600     950   1263
# 4452      90    3500     0     500    963
# 4453     140       0     0     550    550
# 4454     140    4000  1000    1350   1650
#
# [4455 rows x 14 columns]

# %%
status_values = {
    1:'ok',
    2:'default',
    0:'unk'
}

df.status = df.status.map(status_values)

home_values = {
    1:'route',
    2:'owner',
    3:'private',
    4:'ignore',
    5:'parents',
    6:'other',
    0:'unk'
}

df.home = df.home.map(home_values)

marital_values = {
    0:'unk',
    1:'single',
    2:'married',
    3:'widow',
    4:'separated',
    5:'divorced',
}

df.marital = df.marital.map(marital_values)

records_values = {
1: 'no',
2: 'yes',
0: 'unk'
}

df.records = df.records.map(records_values)

job_values = {
1: 'fixed',
2: 'parttime',
3: 'freelance',
4: 'others',
0: 'unk'
}

df.job = df.job.map(job_values)
df
# Out:
#        status  seniority   home  time  age  marital records        job  \
# 0          ok          9  route    60   30  married      no  freelance
# 1          ok         17  route    60   58    widow      no      fixed
# 2     default         10  owner    36   46  married     yes  freelance
# 3          ok          0  route    60   24   single      no      fixed
# 4          ok          0  route    36   26   single      no      fixed
# ...       ...        ...    ...   ...  ...      ...     ...        ...
# 4450  default          1  route    60   39  married      no      fixed
# 4451       ok         22  owner    60   46  married      no      fixed
# 4452  default          0  owner    24   37  married      no   parttime
# 4453       ok          0  route    48   23   single      no  freelance
# 4454       ok          5  owner    60   32  married      no  freelance
#
#       expenses  income  assets  debt  amount  price
# 0           73     129       0     0     800    846
# 1           48     131       0     0    1000   1658
# 2           90     200    3000     0    2000   2985
# 3           63     182    2500     0     900   1325
# 4           46     107       0     0     310    910
# ...        ...     ...     ...   ...     ...    ...
# 4450        69      92       0     0     900   1020
# 4451        60      75    3000   600     950   1263
# 4452        60      90    3500     0     500    963
# 4453        49     140       0     0     550    550
# 4454        60     140    4000  1000    1350   1650
#
# [4455 rows x 14 columns]

# %%
df.describe().round()
# Out:
#        seniority    time     age  expenses      income      assets  \
# count     4455.0  4455.0  4455.0    4455.0      4455.0      4455.0
# mean         8.0    46.0    37.0      56.0    763317.0   1060341.0
# std          8.0    15.0    11.0      20.0   8703625.0  10217569.0
# min          0.0     6.0    18.0      35.0         0.0         0.0
# 25%          2.0    36.0    28.0      35.0        80.0         0.0
# 50%          5.0    48.0    36.0      51.0       120.0      3500.0
# 75%         12.0    60.0    45.0      72.0       166.0      6000.0
# max         48.0    72.0    68.0     180.0  99999999.0  99999999.0
#
#              debt  amount    price
# count      4455.0  4455.0   4455.0
# mean     404382.0  1039.0   1463.0
# std     6344253.0   475.0    628.0
# min           0.0   100.0    105.0
# 25%           0.0   700.0   1118.0
# 50%           0.0  1000.0   1400.0
# 75%           0.0  1300.0   1692.0
# max    99999999.0  5000.0  11140.0

# %%
for c in['income', 'assets', 'debt']:
    df[c] = df[c].replace(to_replace = 99999999, value = np.nan)
df.describe().round()
# Out:
#        seniority    time     age  expenses  income    assets     debt  amount  \
# count     4455.0  4455.0  4455.0    4455.0  4421.0    4408.0   4437.0  4455.0
# mean         8.0    46.0    37.0      56.0   131.0    5403.0    343.0  1039.0
# std          8.0    15.0    11.0      20.0    86.0   11573.0   1246.0   475.0
# min          0.0     6.0    18.0      35.0     0.0       0.0      0.0   100.0
# 25%          2.0    36.0    28.0      35.0    80.0       0.0      0.0   700.0
# 50%          5.0    48.0    36.0      51.0   120.0    3000.0      0.0  1000.0
# 75%         12.0    60.0    45.0      72.0   165.0    6000.0      0.0  1300.0
# max         48.0    72.0    68.0     180.0   959.0  300000.0  30000.0  5000.0
#
#          price
# count   4455.0
# mean    1463.0
# std      628.0
# min      105.0
# 25%     1118.0
# 50%     1400.0
# 75%     1692.0
# max    11140.0

# %%
df.isnull().sum()
# Out:
# status        0
# seniority     0
# home          0
# time          0
# age           0
# marital       0
# records       0
# job           0
# expenses      0
# income       34
# assets       47
# debt         18
# amount        0
# price         0
# dtype: int64

# %%
df.status.value_counts()
# Out:
# status
# ok         3200
# default    1254
# unk           1
# Name: count, dtype: int64

# %%
df = df[df.status != 'unk']

# %%
df_train_full, df_test = train_test_split(df, test_size = 0.2, random_state = 11)
df_train, df_val = train_test_split(df_train_full, test_size = 0.25, random_state = 11)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (2672, 891, 891)

# %%
y_train = (df_train.status == 'default').values
y_val = (df_val.status == 'default').values

# %%
del df_train['status']
del df_val['status']

# %%
dict_train = df_train.fillna(0).to_dict(orient='records')
dict_val = df_val.fillna(0).to_dict(orient='records')

dict_train[0]
# Out:
# {'seniority': 10,
#  'home': 'owner',
#  'time': 36,
#  'age': 36,
#  'marital': 'married',
#  'records': 'no',
#  'job': 'freelance',
#  'expenses': 75,
#  'income': 0.0,
#  'assets': 10000.0,
#  'debt': 0.0,
#  'amount': 1000,
#  'price': 1400}

# %%
dv = DictVectorizer(sparse=False)

X_train = dv.fit_transform(dict_train)
X_val = dv.transform(dict_val)

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict_proba(X_train)[:, 1]
roc_auc_score(y_train, y_pred)
# Out:
# 1.0

# %%
y_pred = dt.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# 0.6583335351529389

# %%
dt = DecisionTreeClassifier(max_depth=2)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
tree_text = export_text(dt, feature_names=dv.feature_names_)
print(tree_text)
# Out:
# |--- records=yes <= 0.50
# |   |--- job=parttime <= 0.50
# |   |   |--- class: False
# |   |--- job=parttime >  0.50
# |   |   |--- class: True
# |--- records=yes >  0.50
# |   |--- seniority <= 6.50
# |   |   |--- class: True
# |   |--- seniority >  6.50
# |   |   |--- class: False

# %%
y_pred = dt.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred)
print('train auc', auc)

y_pred = dt.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred)
print('validation auc', auc)
# Out:
# train auc 0.7054989859726213
# validation auc 0.6685264343319367

# %%
for depth in [1, 2, 3, 4, 5, 6, 10, 15, 20, None]:
    dt = DecisionTreeClassifier(max_depth=depth)
    
    dt.fit(X_train, y_train)
    y_pred = dt.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_pred)
    print('%4s -> %.3f' % (depth, auc))
# Out:
#    1 -> 0.606
#    2 -> 0.669
#    3 -> 0.739
#    4 -> 0.761
#    5 -> 0.766
#    6 -> 0.752
#   10 -> 0.685
#   15 -> 0.664
#   20 -> 0.662
# None -> 0.656

# %%
for m in [4, 5, 6]:
    print('depth: %s' % m)

    for s in [1,5,10,15,20,50,100,200]:
        dt = DecisionTreeClassifier(max_depth=m, min_samples_leaf=s)
        dt.fit(X_train, y_train)
        y_pred = dt.predict_proba(X_val)[:,1]
        auc = roc_auc_score(y_val, y_pred)
        print('%s -> %.3f' %(s,auc))
    print()
# Out:
# depth: 4
# 1 -> 0.761
# 5 -> 0.761
# 10 -> 0.761
# 15 -> 0.764
# 20 -> 0.761
# 50 -> 0.753
# 100 -> 0.756
# 200 -> 0.747
#
# depth: 5
# 1 -> 0.766
# 5 -> 0.768
# 10 -> 0.762
# 15 -> 0.772
# 20 -> 0.774
# 50 -> 0.767
# 100 -> 0.763
# 200 -> 0.759
#
# depth: 6
# 1 -> 0.749
# 5 -> 0.762
# 10 -> 0.778
# 15 -> 0.785
# 20 -> 0.774
# 50 -> 0.772
# 100 -> 0.776
# 200 -> 0.768

# %%
dt = DecisionTreeClassifier(max_depth=6, min_samples_leaf=15)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=15)

# %%
rf = RandomForestClassifier(n_estimators=10, random_state=3)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=3)

# %%
y_pred = rf.predict_proba(X_val)[:,1]
roc_auc_score(y_val, y_pred)
# Out:
# 0.7811145285897654

# %%
aucs = []

for i in range(10, 201, 10):
    rf = RandomForestClassifier(n_estimators=i, random_state=3)
    rf.fit(X_train, y_train)

    y_pred = rf.predict_proba(X_val)[:,1]
    auc = roc_auc_score(y_val, y_pred)
    print('%s -> %.3f' %(i, auc))

    aucs.append(auc)
# Out:
# 10 -> 0.781
# 20 -> 0.801
# 30 -> 0.813
# 40 -> 0.815
# 50 -> 0.816
# 60 -> 0.817
# 70 -> 0.818
# 80 -> 0.818
# 90 -> 0.820
# 100 -> 0.819
# 110 -> 0.819
# 120 -> 0.821
# 130 -> 0.822
# 140 -> 0.822
# 150 -> 0.820
# 160 -> 0.820
# 170 -> 0.819
# 180 -> 0.820
# 190 -> 0.820
# 200 -> 0.820

# %%
plt.plot(range(10, 201, 10), aucs)

# %%
all_aucs = {}

for depth in [5, 10, 20]:
    print('depth: %s' % depth)
    aucs = []

    for i in range(10, 201, 10):
        rf = RandomForestClassifier(n_estimators=i, max_depth=depth, random_state=1)
        rf.fit(X_train, y_train)
        y_pred = rf.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)
        print('%s -> %.3f' % (i, auc))
        aucs.append(auc)
    
    all_aucs[depth] = aucs
    print()
# Out:
# depth: 5
# 10 -> 0.788
# 20 -> 0.798
# 30 -> 0.800
# 40 -> 0.800
# 50 -> 0.800
# 60 -> 0.801
# 70 -> 0.802
# 80 -> 0.803
# 90 -> 0.804
# 100 -> 0.804
# 110 -> 0.807
# 120 -> 0.806
# 130 -> 0.808
# 140 -> 0.807
# 150 -> 0.807
# 160 -> 0.807
# 170 -> 0.807
# 180 -> 0.807
# 190 -> 0.807
# 200 -> 0.807
#
# depth: 10
# 10 -> 0.791
# 20 -> 0.808
# 30 -> 0.812
# 40 -> 0.818
# 50 -> 0.817
# 60 -> 0.819
# 70 -> 0.820
# 80 -> 0.820
# 90 -> 0.820
# 100 -> 0.821
# 110 -> 0.823
# 120 -> 0.823
# 130 -> 0.825
# 140 -> 0.824
# 150 -> 0.824
# 160 -> 0.825
# 170 -> 0.825
# 180 -> 0.825
# 190 -> 0.825
# 200 -> 0.825
#
# depth: 20
# 10 -> 0.776
# 20 -> 0.803
# 30 -> 0.813
# 40 -> 0.817
# 50 -> 0.815
# 60 -> 0.813
# 70 -> 0.814
# 80 -> 0.815
# 90 -> 0.814
# 100 -> 0.815
# 110 -> 0.817
# 120 -> 0.816
# 130 -> 0.818
# 140 -> 0.818
# 150 -> 0.818
# 160 -> 0.818
# 170 -> 0.817
# 180 -> 0.817
# 190 -> 0.817
# 200 -> 0.818

# %%
num_trees = list(range(10, 201, 10))
plt.plot(num_trees, all_aucs[5], label = 'depth = 5')
plt.plot(num_trees, all_aucs[10], label = 'depth = 10')
plt.plot(num_trees, all_aucs[20], label = 'depth = 20')
plt.legend()

# %%
all_aucs = {}

for m in [3,5,10]:
    print ('min_samples_leaf: %s' % m)
    aucs = []

    for i in range (10, 201, 20):
        rf = RandomForestClassifier(n_estimators=i, max_depth=10, min_samples_leaf = m, random_state = 1)
        rf.fit(X_train, y_train)
        y_pred = rf.predict_proba(X_val)[:,1]
        auc = roc_auc_score(y_val, y_pred)
        print('%s -> %.3f' %(i, auc))
        aucs.append(auc)
    all_aucs[m] = aucs
    print()
# Out:
# min_samples_leaf: 3
# 10 -> 0.811
# 30 -> 0.823
# 50 -> 0.823
# 70 -> 0.822
# 90 -> 0.823
# 110 -> 0.823
# 130 -> 0.824
# 150 -> 0.825
# 170 -> 0.825
# 190 -> 0.825
#
# min_samples_leaf: 5
# 10 -> 0.813
# 30 -> 0.818
# 50 -> 0.821
# 70 -> 0.822
# 90 -> 0.822
# 110 -> 0.825
# 130 -> 0.825
# 150 -> 0.825
# 170 -> 0.825
# 190 -> 0.826
#
# min_samples_leaf: 10
# 10 -> 0.810
# 30 -> 0.822
# 50 -> 0.822
# 70 -> 0.819
# 90 -> 0.820
# 110 -> 0.820
# 130 -> 0.821
# 150 -> 0.820
# 170 -> 0.820
# 190 -> 0.820

# %%
num_trees = list(range(10, 201, 20))
plt.plot(num_trees, all_aucs[3], label = 'min_samples_leaf = 3')
plt.plot(num_trees, all_aucs[5], label = 'min_samples_leaf = 5')
plt.plot(num_trees, all_aucs[10], label = 'min_samples_leaf = 10')
plt.legend()

# %%
rf = RandomForestClassifier(n_estimators=200, max_depth=10, min_samples_leaf=5, random_state=1)

# %%
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=dv.feature_names_)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=dv.feature_names_)

# %%
xgb_params = {
    'eta':0.3,
    'max_depth':6,
    'min_child_weight':1,
    'object': 'binary:logistic',
    'nthread':8,
    'seed':1,
    'silent':1
}

# %%
model = xgb.train(xgb_params, dtrain, num_boost_round=10)
# Out:
# c:\Users\klmv0\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:21:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "object", "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
y_pred = model.predict(dval)
y_pred
# Out:
# array([ 1.54598340e-01,  6.15349710e-02,  1.76486149e-02,  1.89191625e-01,
#         4.88535501e-02,  7.56340995e-02,  3.06857526e-02,  3.73894453e-01,
#         4.25379515e-01,  8.46345676e-04,  2.42446259e-01,  5.55510402e-01,
#         5.17776310e-01,  6.97570443e-02,  2.65803784e-01,  5.52247941e-01,
#         6.66836649e-02,  5.91248035e-01,  7.67483339e-02,  2.46058539e-01,
#         5.25968596e-02,  3.78473938e-01,  7.62828812e-02,  3.43922257e-01,
#         5.75416565e-01,  1.57723770e-01,  7.01737165e-01,  2.81517863e-01,
#         8.44978511e-01,  3.10517810e-02,  1.00256848e+00,  3.72522593e-01,
#         2.91718900e-01,  3.20961446e-01, -2.21782108e-03, -2.29897536e-02,
#         1.05509102e+00,  4.98663932e-01,  2.44396612e-01,  6.55785561e-01,
#         7.18270317e-02,  9.61436450e-01,  3.27577181e-02,  5.13085306e-01,
#         7.01557659e-03,  5.80016077e-02,  4.47357029e-01, -6.45187451e-04,
#         1.00544371e-01,  1.05772555e-01,  1.39325960e-02,  2.76873440e-01,
#         5.37870713e-02,  3.41462821e-01,  4.97945726e-01,  2.23516822e-01,
#         3.76750201e-01,  2.14449137e-01,  1.65083110e-02,  8.28068778e-02,
#         3.28907698e-01, -3.11352499e-02,  1.54066399e-01,  1.23917088e-01,
#         1.97670624e-01,  7.86238313e-01,  3.20285022e-01,  2.61565357e-01,
#         2.83749066e-02,  7.94875562e-01,  1.37174323e-01,  5.64026773e-01,
#         9.29737166e-02,  1.64253548e-01,  1.96693718e-01,  3.24342251e-01,
#         4.22012918e-02,  2.44015574e-01,  1.42464489e-01,  1.67767275e-02,
#         2.01025173e-01,  4.00719419e-02, -7.14295590e-03,  3.31588797e-02,
#         2.01379701e-01,  1.02830625e+00,  1.75800800e-01,  2.50714362e-01,
#         9.86201391e-02,  8.45946550e-01,  2.82661676e-01,  1.56101584e-01,
#         4.18783873e-02,  1.73007816e-01,  3.72711420e-02,  2.11606443e-01,
#         2.73236364e-01,  2.91706711e-01,  1.66075259e-01,  7.87849903e-01,
#         5.31248935e-02,  7.04524040e-01,  6.63695559e-02,  3.12551171e-01,
#         2.17703253e-01,  2.24928260e-01,  4.05683756e-01,  6.44689053e-02,
#         5.71836770e-01,  7.31463790e-01,  3.55314702e-01,  1.78686500e-01,
#         7.86198199e-01,  6.44769013e-01,  6.84541836e-02,  1.59270763e-01,
#         6.54790550e-02,  9.05652046e-02,  2.53619343e-01,  6.30900383e-01,
#         1.99761719e-01,  5.73091861e-03,  2.95552760e-01,  2.89940208e-01,
#         1.45317137e-01, -2.56370078e-03,  6.98964894e-02,  5.19487619e-01,
#         1.77314103e-01,  8.55599105e-01,  1.86372697e-01,  1.37899602e-02,
#         7.79216826e-01,  2.90413618e-01,  1.82951093e-01,  1.30294422e-02,
#         8.89746621e-02,  6.57924041e-02,  2.73293376e-01,  9.68437195e-02,
#         5.72529212e-02,  1.76033437e-01,  1.16852172e-01,  1.30118564e-01,
#        -1.29318265e-02,  3.13974798e-01, -1.36577990e-02,  5.57469487e-01,
#         1.78144276e-01,  3.43895406e-02,  5.10579824e-01,  6.21674001e-01,
#         3.20285022e-01,  2.84258902e-01,  1.42319888e-01,  5.14731482e-02,
#         6.21174634e-01,  4.10859771e-02,  4.14531916e-01], dtype=float32)

# %%
roc_auc_score(y_val, y_pred)
# Out:
# 0.8039615170376111

# %%
watchlist = [(dtrain, 'train'), (dval, 'val')]

# %%
xgb_params = {
    'eta':0.3,
    'max_depth':6,
    'min_child_weight':1,
    'object': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread':8,
    'seed':1,
    'silent':1
}

# %%
model = xgb.train(xgb_params, dtrain, num_boost_round=100, evals=watchlist, verbose_eval=10)
# Out:
# [0]	train-auc:0.87616	val-auc:0.77997
# [10]	train-auc:0.96161	val-auc:0.80536
# [20]	train-auc:0.98202	val-auc:0.80764
# [30]	train-auc:0.99180	val-auc:0.80005
# [40]	train-auc:0.99630	val-auc:0.79989
# [50]	train-auc:0.99871	val-auc:0.79348
# c:\Users\klmv0\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:28:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "object", "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [60]	train-auc:0.99962	val-auc:0.79277
# [70]	train-auc:0.99990	val-auc:0.79423
# [80]	train-auc:0.99997	val-auc:0.79213
# [90]	train-auc:0.99999	val-auc:0.79094
# [99]	train-auc:1.00000	val-auc:0.79153

# %%
xgb_params = {
    'eta':0.1,
    'max_depth':6,
    'min_child_weight':1,
    'object': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread':8,
    'seed':1,
    'silent':1
}

model = xgb.train(xgb_params, dtrain, num_boost_round=500, evals=watchlist, verbose_eval=10)
# Out:
# [0]	train-auc:0.87616	val-auc:0.77997
# [10]	train-auc:0.92809	val-auc:0.81133
# [20]	train-auc:0.95027	val-auc:0.81555
# [30]	train-auc:0.96424	val-auc:0.81981
# [40]	train-auc:0.97321	val-auc:0.82523
# [50]	train-auc:0.97846	val-auc:0.82654
# c:\Users\klmv0\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:34:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "object", "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [60]	train-auc:0.98299	val-auc:0.82383
# [70]	train-auc:0.98581	val-auc:0.82196
# [80]	train-auc:0.98790	val-auc:0.82088
# [90]	train-auc:0.99077	val-auc:0.82007
# [100]	train-auc:0.99373	val-auc:0.81934
# [110]	train-auc:0.99520	val-auc:0.81917
# [120]	train-auc:0.99653	val-auc:0.81706
# [130]	train-auc:0.99752	val-auc:0.81640
# [140]	train-auc:0.99810	val-auc:0.81540
# [150]	train-auc:0.99860	val-auc:0.81367
# [160]	train-auc:0.99903	val-auc:0.81085
# [170]	train-auc:0.99919	val-auc:0.80955
# [180]	train-auc:0.99943	val-auc:0.81017
# [190]	train-auc:0.99954	val-auc:0.80962
# [200]	train-auc:0.99965	val-auc:0.80942
# [210]	train-auc:0.99976	val-auc:0.80911
# [220]	train-auc:0.99982	val-auc:0.80857
# [230]	train-auc:0.99988	val-auc:0.80777
# [240]	train-auc:0.99995	val-auc:0.80657
# [250]	train-auc:0.99996	val-auc:0.80690
# [260]	train-auc:0.99997	val-auc:0.80667
# [270]	train-auc:0.99998	val-auc:0.80659
# [280]	train-auc:0.99999	val-auc:0.80626
# [290]	train-auc:0.99999	val-auc:0.80571
# [300]	train-auc:0.99999	val-auc:0.80543
# [310]	train-auc:0.99999	val-auc:0.80531
# [320]	train-auc:1.00000	val-auc:0.80416
# [330]	train-auc:1.00000	val-auc:0.80363
# [340]	train-auc:1.00000	val-auc:0.80311
# [350]	train-auc:1.00000	val-auc:0.80308
# [360]	train-auc:1.00000	val-auc:0.80270
# [370]	train-auc:1.00000	val-auc:0.80196
# [380]	train-auc:1.00000	val-auc:0.80179
# [390]	train-auc:1.00000	val-auc:0.80129
# [400]	train-auc:1.00000	val-auc:0.80133
# [410]	train-auc:1.00000	val-auc:0.80107
# [420]	train-auc:1.00000	val-auc:0.80090
# [430]	train-auc:1.00000	val-auc:0.80047
# [440]	train-auc:1.00000	val-auc:0.80027
# [450]	train-auc:1.00000	val-auc:0.79935
# [460]	train-auc:1.00000	val-auc:0.79967
# [470]	train-auc:1.00000	val-auc:0.79971
# [480]	train-auc:1.00000	val-auc:0.79940
# [490]	train-auc:1.00000	val-auc:0.79932
# [499]	train-auc:1.00000	val-auc:0.79946

# %%
xgb_params = {
    'eta':0.05,
    'max_depth':6,
    'min_child_weight':1,
    'object': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread':8,
    'seed':1,
    'silent':1
}

model = xgb.train(xgb_params, dtrain, num_boost_round=500, evals=watchlist, verbose_eval=10)
# Out:
# [0]	train-auc:0.87616	val-auc:0.77997
# [10]	train-auc:0.90319	val-auc:0.80807
# [20]	train-auc:0.92345	val-auc:0.81454
# [30]	train-auc:0.93598	val-auc:0.81740
# [40]	train-auc:0.94822	val-auc:0.82173
# [50]	train-auc:0.95787	val-auc:0.82224
# c:\Users\klmv0\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:35:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "object", "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [60]	train-auc:0.96469	val-auc:0.82321
# [70]	train-auc:0.96973	val-auc:0.82362
# [80]	train-auc:0.97327	val-auc:0.82391
# [90]	train-auc:0.97682	val-auc:0.82417
# [100]	train-auc:0.97953	val-auc:0.82390
# [110]	train-auc:0.98089	val-auc:0.82434
# [120]	train-auc:0.98242	val-auc:0.82569
# [130]	train-auc:0.98359	val-auc:0.82625
# [140]	train-auc:0.98446	val-auc:0.82699
# [150]	train-auc:0.98586	val-auc:0.82662
# [160]	train-auc:0.98723	val-auc:0.82722
# [170]	train-auc:0.98862	val-auc:0.82773
# [180]	train-auc:0.98937	val-auc:0.82762
# [190]	train-auc:0.98989	val-auc:0.82803
# [200]	train-auc:0.99059	val-auc:0.82813
# [210]	train-auc:0.99124	val-auc:0.82762
# [220]	train-auc:0.99236	val-auc:0.82707
# [230]	train-auc:0.99307	val-auc:0.82650
# [240]	train-auc:0.99388	val-auc:0.82615
# [250]	train-auc:0.99430	val-auc:0.82595
# [260]	train-auc:0.99489	val-auc:0.82608
# [270]	train-auc:0.99573	val-auc:0.82520
# [280]	train-auc:0.99660	val-auc:0.82421
# [290]	train-auc:0.99725	val-auc:0.82264
# [300]	train-auc:0.99760	val-auc:0.82230
# [310]	train-auc:0.99779	val-auc:0.82217
# [320]	train-auc:0.99810	val-auc:0.82141
# [330]	train-auc:0.99835	val-auc:0.82116
# [340]	train-auc:0.99848	val-auc:0.82045
# [350]	train-auc:0.99878	val-auc:0.81933
# [360]	train-auc:0.99883	val-auc:0.81915
# [370]	train-auc:0.99901	val-auc:0.81879
# [380]	train-auc:0.99912	val-auc:0.81800
# [390]	train-auc:0.99919	val-auc:0.81791
# [400]	train-auc:0.99937	val-auc:0.81834
# [410]	train-auc:0.99944	val-auc:0.81791
# [420]	train-auc:0.99951	val-auc:0.81754
# [430]	train-auc:0.99954	val-auc:0.81738
# [440]	train-auc:0.99958	val-auc:0.81697
# [450]	train-auc:0.99963	val-auc:0.81717
# [460]	train-auc:0.99968	val-auc:0.81654
# [470]	train-auc:0.99975	val-auc:0.81613
# [480]	train-auc:0.99978	val-auc:0.81628
# [490]	train-auc:0.99979	val-auc:0.81597
# [499]	train-auc:0.99980	val-auc:0.81576

# %%
xgb_params = {
    'eta':0.01,
    'max_depth':6,
    'min_child_weight':1,
    'object': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread':8,
    'seed':1,
    'silent':1
}

model = xgb.train(xgb_params, dtrain, num_boost_round=500, evals=watchlist, verbose_eval=10)
# Out:
# [0]	train-auc:0.87616	val-auc:0.77997
# [10]	train-auc:0.88216	val-auc:0.78311
# [20]	train-auc:0.88694	val-auc:0.78729
# [30]	train-auc:0.89193	val-auc:0.79410
# [40]	train-auc:0.89693	val-auc:0.80108
# [50]	train-auc:0.90225	val-auc:0.80670
# [60]	train-auc:0.90831	val-auc:0.81049
# c:\Users\klmv0\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:35:39] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "object", "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [70]	train-auc:0.91271	val-auc:0.81196
# [80]	train-auc:0.91648	val-auc:0.81268
# [90]	train-auc:0.91943	val-auc:0.81255
# [100]	train-auc:0.92211	val-auc:0.81388
# [110]	train-auc:0.92506	val-auc:0.81535
# [120]	train-auc:0.92790	val-auc:0.81590
# [130]	train-auc:0.93015	val-auc:0.81609
# [140]	train-auc:0.93215	val-auc:0.81674
# [150]	train-auc:0.93499	val-auc:0.81769
# [160]	train-auc:0.93815	val-auc:0.81871
# [170]	train-auc:0.94102	val-auc:0.81966
# [180]	train-auc:0.94312	val-auc:0.82085
# [190]	train-auc:0.94529	val-auc:0.82144
# [200]	train-auc:0.94724	val-auc:0.82178
# [210]	train-auc:0.94920	val-auc:0.82160
# [220]	train-auc:0.95117	val-auc:0.82226
# [230]	train-auc:0.95306	val-auc:0.82237
# [240]	train-auc:0.95455	val-auc:0.82308
# [250]	train-auc:0.95606	val-auc:0.82362
# [260]	train-auc:0.95737	val-auc:0.82345
# [270]	train-auc:0.95863	val-auc:0.82351
# [280]	train-auc:0.95988	val-auc:0.82317
# [290]	train-auc:0.96122	val-auc:0.82328
# [300]	train-auc:0.96246	val-auc:0.82331
# [310]	train-auc:0.96357	val-auc:0.82347
# [320]	train-auc:0.96479	val-auc:0.82364
# [330]	train-auc:0.96601	val-auc:0.82389
# [340]	train-auc:0.96702	val-auc:0.82355
# [350]	train-auc:0.96785	val-auc:0.82380
# [360]	train-auc:0.96862	val-auc:0.82330
# [370]	train-auc:0.96942	val-auc:0.82338
# [380]	train-auc:0.97017	val-auc:0.82346
# [390]	train-auc:0.97105	val-auc:0.82373
# [400]	train-auc:0.97182	val-auc:0.82368
# [410]	train-auc:0.97233	val-auc:0.82389
# [420]	train-auc:0.97293	val-auc:0.82420
# [430]	train-auc:0.97356	val-auc:0.82464
# [440]	train-auc:0.97416	val-auc:0.82484
# [450]	train-auc:0.97475	val-auc:0.82493
# [460]	train-auc:0.97536	val-auc:0.82548
# [470]	train-auc:0.97588	val-auc:0.82575
# [480]	train-auc:0.97639	val-auc:0.82598
# [490]	train-auc:0.97686	val-auc:0.82618
# [499]	train-auc:0.97741	val-auc:0.82659

# %%
xgb_params = {
    'eta':0.1,
    'max_depth':3,
    'min_child_weight':1,
    'object': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread':8,
    'seed':1,
    'silent':1
}

model = xgb.train(xgb_params, dtrain, num_boost_round=500, evals=watchlist, verbose_eval=10)
# Out:
# [0]	train-auc:0.77610	val-auc:0.73891
# [10]	train-auc:0.85102	val-auc:0.79801
# [20]	train-auc:0.86834	val-auc:0.81368
# [30]	train-auc:0.88247	val-auc:0.82140
# [40]	train-auc:0.89229	val-auc:0.82573
# [50]	train-auc:0.89899	val-auc:0.82720
# [60]	train-auc:0.90428	val-auc:0.82697
# [70]	train-auc:0.90861	val-auc:0.82834
# [80]	train-auc:0.91254	val-auc:0.82948
# [90]	train-auc:0.91499	val-auc:0.83102
# c:\Users\klmv0\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:36:39] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "object", "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [100]	train-auc:0.91828	val-auc:0.83162
# [110]	train-auc:0.92142	val-auc:0.83291
# [120]	train-auc:0.92389	val-auc:0.83273
# [130]	train-auc:0.92569	val-auc:0.83256
# [140]	train-auc:0.92838	val-auc:0.83216
# [150]	train-auc:0.93033	val-auc:0.83123
# [160]	train-auc:0.93202	val-auc:0.83167
# [170]	train-auc:0.93475	val-auc:0.83160
# [180]	train-auc:0.93671	val-auc:0.83205
# [190]	train-auc:0.93814	val-auc:0.83168
# [200]	train-auc:0.93939	val-auc:0.83162
# [210]	train-auc:0.94124	val-auc:0.83022
# [220]	train-auc:0.94260	val-auc:0.83044
# [230]	train-auc:0.94453	val-auc:0.83069
# [240]	train-auc:0.94552	val-auc:0.83063
# [250]	train-auc:0.94611	val-auc:0.83018
# [260]	train-auc:0.94721	val-auc:0.83027
# [270]	train-auc:0.94887	val-auc:0.83007
# [280]	train-auc:0.94969	val-auc:0.82984
# [290]	train-auc:0.95091	val-auc:0.82971
# [300]	train-auc:0.95194	val-auc:0.82971
# [310]	train-auc:0.95302	val-auc:0.82926
# [320]	train-auc:0.95387	val-auc:0.82890
# [330]	train-auc:0.95554	val-auc:0.82911
# [340]	train-auc:0.95739	val-auc:0.82879
# [350]	train-auc:0.95905	val-auc:0.82869
# [360]	train-auc:0.96038	val-auc:0.82820
# [370]	train-auc:0.96129	val-auc:0.82861
# [380]	train-auc:0.96216	val-auc:0.82837
# [390]	train-auc:0.96356	val-auc:0.82806
# [400]	train-auc:0.96446	val-auc:0.82867
# [410]	train-auc:0.96575	val-auc:0.82886
# [420]	train-auc:0.96690	val-auc:0.82806
# [430]	train-auc:0.96794	val-auc:0.82775
# [440]	train-auc:0.96883	val-auc:0.82822
# [450]	train-auc:0.96941	val-auc:0.82824
# [460]	train-auc:0.96998	val-auc:0.82790
# [470]	train-auc:0.97081	val-auc:0.82772
# [480]	train-auc:0.97156	val-auc:0.82821
# [490]	train-auc:0.97234	val-auc:0.82770
# [499]	train-auc:0.97284	val-auc:0.82724

# %%
xgb_params = {
    'eta':0.1,
    'max_depth':10,
    'min_child_weight':1,
    'object': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread':8,
    'seed':1,
    'silent':1
}

model = xgb.train(xgb_params, dtrain, num_boost_round=500, evals=watchlist, verbose_eval=10)
# Out:
# [0]	train-auc:0.96336	val-auc:0.74628
# [10]	train-auc:0.99430	val-auc:0.79233
# c:\Users\klmv0\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:36:59] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "object", "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [20]	train-auc:0.99865	val-auc:0.79482
# [30]	train-auc:0.99981	val-auc:0.79559
# [40]	train-auc:0.99999	val-auc:0.79919
# [50]	train-auc:1.00000	val-auc:0.80048
# [60]	train-auc:1.00000	val-auc:0.79902
# [70]	train-auc:1.00000	val-auc:0.79930
# [80]	train-auc:1.00000	val-auc:0.80062
# [90]	train-auc:1.00000	val-auc:0.80053
# [100]	train-auc:1.00000	val-auc:0.80035
# [110]	train-auc:1.00000	val-auc:0.80049
# [120]	train-auc:1.00000	val-auc:0.80079
# [130]	train-auc:1.00000	val-auc:0.80122
# [140]	train-auc:1.00000	val-auc:0.80075
# [150]	train-auc:1.00000	val-auc:0.80025
# [160]	train-auc:1.00000	val-auc:0.80006
# [170]	train-auc:1.00000	val-auc:0.80029
# [180]	train-auc:1.00000	val-auc:0.80006
# [190]	train-auc:1.00000	val-auc:0.80012
# [200]	train-auc:1.00000	val-auc:0.80023
# [210]	train-auc:1.00000	val-auc:0.80025
# [220]	train-auc:1.00000	val-auc:0.80052
# [230]	train-auc:1.00000	val-auc:0.80040
# [240]	train-auc:1.00000	val-auc:0.80037
# [250]	train-auc:1.00000	val-auc:0.80055
# [260]	train-auc:1.00000	val-auc:0.80060
# [270]	train-auc:1.00000	val-auc:0.80038
# [280]	train-auc:1.00000	val-auc:0.80028
# [290]	train-auc:1.00000	val-auc:0.80027
# [300]	train-auc:1.00000	val-auc:0.80036
# [310]	train-auc:1.00000	val-auc:0.80027
# [320]	train-auc:1.00000	val-auc:0.80027
# [330]	train-auc:1.00000	val-auc:0.80026
# [340]	train-auc:1.00000	val-auc:0.80030
# [350]	train-auc:1.00000	val-auc:0.80034
# [360]	train-auc:1.00000	val-auc:0.80034
# [370]	train-auc:1.00000	val-auc:0.80034
# [380]	train-auc:1.00000	val-auc:0.80034
# [390]	train-auc:1.00000	val-auc:0.80034
# [400]	train-auc:1.00000	val-auc:0.80034
# [410]	train-auc:1.00000	val-auc:0.80034
# [420]	train-auc:1.00000	val-auc:0.80034
# [430]	train-auc:1.00000	val-auc:0.80034
# [440]	train-auc:1.00000	val-auc:0.80034
# [450]	train-auc:1.00000	val-auc:0.80034
# [460]	train-auc:1.00000	val-auc:0.80034
# [470]	train-auc:1.00000	val-auc:0.80034
# [480]	train-auc:1.00000	val-auc:0.80034
# [490]	train-auc:1.00000	val-auc:0.80034
# [499]	train-auc:1.00000	val-auc:0.80034

# %%
xgb_params = {
    'eta':0.1,
    'max_depth':6,
    'min_child_weight':10,
    'object': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread':8,
    'seed':1,
    'silent':1
}

model = xgb.train(xgb_params, dtrain, num_boost_round=500, evals=watchlist, verbose_eval=10)
# Out:
# [0]	train-auc:0.86617	val-auc:0.78019
# [10]	train-auc:0.90945	val-auc:0.80627
# [20]	train-auc:0.93379	val-auc:0.81932
# [30]	train-auc:0.94908	val-auc:0.81913
# [40]	train-auc:0.95911	val-auc:0.82122
# [50]	train-auc:0.96587	val-auc:0.82104
# [60]	train-auc:0.97228	val-auc:0.82220
# [70]	train-auc:0.97649	val-auc:0.82198
# [80]	train-auc:0.97938	val-auc:0.82376
# [90]	train-auc:0.98234	val-auc:0.82391
# c:\Users\klmv0\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:39:38] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "object", "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [100]	train-auc:0.98522	val-auc:0.82325
# [110]	train-auc:0.98770	val-auc:0.82238
# [120]	train-auc:0.98918	val-auc:0.82104
# [130]	train-auc:0.99076	val-auc:0.81886
# [140]	train-auc:0.99232	val-auc:0.81765
# [150]	train-auc:0.99293	val-auc:0.81623
# [160]	train-auc:0.99444	val-auc:0.81599
# [170]	train-auc:0.99522	val-auc:0.81543
# [180]	train-auc:0.99617	val-auc:0.81414
# [190]	train-auc:0.99660	val-auc:0.81398
# [200]	train-auc:0.99723	val-auc:0.81270
# [210]	train-auc:0.99748	val-auc:0.81177
# [220]	train-auc:0.99776	val-auc:0.81225
# [230]	train-auc:0.99811	val-auc:0.81058
# [240]	train-auc:0.99844	val-auc:0.81058
# [250]	train-auc:0.99867	val-auc:0.81083
# [260]	train-auc:0.99889	val-auc:0.80990
# [270]	train-auc:0.99909	val-auc:0.81008
# [280]	train-auc:0.99931	val-auc:0.81007
# [290]	train-auc:0.99950	val-auc:0.80944
# [300]	train-auc:0.99960	val-auc:0.80939
# [310]	train-auc:0.99969	val-auc:0.80706
# [320]	train-auc:0.99973	val-auc:0.80654
# [330]	train-auc:0.99980	val-auc:0.80672
# [340]	train-auc:0.99981	val-auc:0.80574
# [350]	train-auc:0.99985	val-auc:0.80664
# [360]	train-auc:0.99988	val-auc:0.80637
# [370]	train-auc:0.99992	val-auc:0.80492
# [380]	train-auc:0.99992	val-auc:0.80414
# [390]	train-auc:0.99993	val-auc:0.80289
# [400]	train-auc:0.99994	val-auc:0.80260
# [410]	train-auc:0.99995	val-auc:0.80229
# [420]	train-auc:0.99997	val-auc:0.80160
# [430]	train-auc:0.99998	val-auc:0.80122
# [440]	train-auc:0.99998	val-auc:0.80079
# [450]	train-auc:0.99999	val-auc:0.80021
# [460]	train-auc:0.99999	val-auc:0.79938
# [470]	train-auc:0.99999	val-auc:0.79978
# [480]	train-auc:0.99999	val-auc:0.79882
# [490]	train-auc:0.99999	val-auc:0.79847
# [499]	train-auc:1.00000	val-auc:0.79812

# %%
xgb_params = {
    'eta':0.1,
    'max_depth':6,
    'min_child_weight':30,
    'object': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread':8,
    'seed':1,
    'silent':1
}

model = xgb.train(xgb_params, dtrain, num_boost_round=500, evals=watchlist, verbose_eval=10)
# Out:
# [0]	train-auc:0.85384	val-auc:0.78205
# [10]	train-auc:0.89436	val-auc:0.80943
# [20]	train-auc:0.91319	val-auc:0.82252
# [30]	train-auc:0.92937	val-auc:0.82694
# [40]	train-auc:0.93970	val-auc:0.82842
# [50]	train-auc:0.94701	val-auc:0.82793
# [60]	train-auc:0.95241	val-auc:0.82909
# [70]	train-auc:0.95713	val-auc:0.82854
# [80]	train-auc:0.96170	val-auc:0.82718
# [90]	train-auc:0.96737	val-auc:0.82560
# c:\Users\klmv0\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:39:53] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "object", "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [100]	train-auc:0.96995	val-auc:0.82519
# [110]	train-auc:0.97363	val-auc:0.82430
# [120]	train-auc:0.97570	val-auc:0.82364
# [130]	train-auc:0.97774	val-auc:0.82225
# [140]	train-auc:0.97956	val-auc:0.82015
# [150]	train-auc:0.98118	val-auc:0.81728
# [160]	train-auc:0.98296	val-auc:0.81497
# [170]	train-auc:0.98421	val-auc:0.81402
# [180]	train-auc:0.98508	val-auc:0.81349
# [190]	train-auc:0.98634	val-auc:0.81216
# [200]	train-auc:0.98745	val-auc:0.81174
# [210]	train-auc:0.98861	val-auc:0.81060
# [220]	train-auc:0.98965	val-auc:0.80941
# [230]	train-auc:0.99080	val-auc:0.80929
# [240]	train-auc:0.99168	val-auc:0.80828
# [250]	train-auc:0.99268	val-auc:0.80743
# [260]	train-auc:0.99313	val-auc:0.80652
# [270]	train-auc:0.99349	val-auc:0.80594
# [280]	train-auc:0.99389	val-auc:0.80558
# [290]	train-auc:0.99442	val-auc:0.80427
# [300]	train-auc:0.99475	val-auc:0.80325
# [310]	train-auc:0.99498	val-auc:0.80316
# [320]	train-auc:0.99549	val-auc:0.80199
# [330]	train-auc:0.99599	val-auc:0.80151
# [340]	train-auc:0.99622	val-auc:0.80078
# [350]	train-auc:0.99655	val-auc:0.80067
# [360]	train-auc:0.99701	val-auc:0.80027
# [370]	train-auc:0.99721	val-auc:0.79987
# [380]	train-auc:0.99732	val-auc:0.80076
# [390]	train-auc:0.99753	val-auc:0.80054
# [400]	train-auc:0.99775	val-auc:0.79944
# [410]	train-auc:0.99790	val-auc:0.79900
# [420]	train-auc:0.99805	val-auc:0.79878
# [430]	train-auc:0.99820	val-auc:0.79822
# [440]	train-auc:0.99826	val-auc:0.79721
# [450]	train-auc:0.99839	val-auc:0.79622
# [460]	train-auc:0.99859	val-auc:0.79555
# [470]	train-auc:0.99869	val-auc:0.79515
# [480]	train-auc:0.99879	val-auc:0.79518
# [490]	train-auc:0.99896	val-auc:0.79420
# [499]	train-auc:0.99909	val-auc:0.79422

# %%
xgb_params = {
    'eta':0.1,
    'max_depth':3,
    'min_child_weight':1,
    'object': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread':8,
    'seed':1,
    'silent':1
}

model = xgb.train(xgb_params, dtrain, num_boost_round=500, evals=watchlist, verbose_eval=10)
# Out:
# [0]	train-auc:0.77610	val-auc:0.73891
# [10]	train-auc:0.85102	val-auc:0.79801
# [20]	train-auc:0.86834	val-auc:0.81368
# [30]	train-auc:0.88247	val-auc:0.82140
# [40]	train-auc:0.89229	val-auc:0.82573
# [50]	train-auc:0.89899	val-auc:0.82720
# [60]	train-auc:0.90428	val-auc:0.82697
# [70]	train-auc:0.90861	val-auc:0.82834
# [80]	train-auc:0.91254	val-auc:0.82948
# c:\Users\klmv0\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:40:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "object", "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [90]	train-auc:0.91499	val-auc:0.83102
# [100]	train-auc:0.91828	val-auc:0.83162
# [110]	train-auc:0.92142	val-auc:0.83291
# [120]	train-auc:0.92389	val-auc:0.83273
# [130]	train-auc:0.92569	val-auc:0.83256
# [140]	train-auc:0.92838	val-auc:0.83216
# [150]	train-auc:0.93033	val-auc:0.83123
# [160]	train-auc:0.93202	val-auc:0.83167
# [170]	train-auc:0.93475	val-auc:0.83160
# [180]	train-auc:0.93671	val-auc:0.83205
# [190]	train-auc:0.93814	val-auc:0.83168
# [200]	train-auc:0.93939	val-auc:0.83162
# [210]	train-auc:0.94124	val-auc:0.83022
# [220]	train-auc:0.94260	val-auc:0.83044
# [230]	train-auc:0.94453	val-auc:0.83069
# [240]	train-auc:0.94552	val-auc:0.83063
# [250]	train-auc:0.94611	val-auc:0.83018
# [260]	train-auc:0.94721	val-auc:0.83027
# [270]	train-auc:0.94887	val-auc:0.83007
# [280]	train-auc:0.94969	val-auc:0.82984
# [290]	train-auc:0.95091	val-auc:0.82971
# [300]	train-auc:0.95194	val-auc:0.82971
# [310]	train-auc:0.95302	val-auc:0.82926
# [320]	train-auc:0.95387	val-auc:0.82890
# [330]	train-auc:0.95554	val-auc:0.82911
# [340]	train-auc:0.95739	val-auc:0.82879
# [350]	train-auc:0.95905	val-auc:0.82869
# [360]	train-auc:0.96038	val-auc:0.82820
# [370]	train-auc:0.96129	val-auc:0.82861
# [380]	train-auc:0.96216	val-auc:0.82837
# [390]	train-auc:0.96356	val-auc:0.82806
# [400]	train-auc:0.96446	val-auc:0.82867
# [410]	train-auc:0.96575	val-auc:0.82886
# [420]	train-auc:0.96690	val-auc:0.82806
# [430]	train-auc:0.96794	val-auc:0.82775
# [440]	train-auc:0.96883	val-auc:0.82822
# [450]	train-auc:0.96941	val-auc:0.82824
# [460]	train-auc:0.96998	val-auc:0.82790
# [470]	train-auc:0.97081	val-auc:0.82772
# [480]	train-auc:0.97156	val-auc:0.82821
# [490]	train-auc:0.97234	val-auc:0.82770
# [499]	train-auc:0.97284	val-auc:0.82724

# %%
y_train = (df_train_full.status == 'default').values
y_test = (df_test.status == 'default').values

# %%
del df_train_full['status']
del df_test['status']

# %%
dict_train = df_train_full.fillna(0).to_dict(orient = 'records')
dict_test = df_test.fillna(0).to_dict(orient = 'records')

# %%
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(dict_train)
X_test = dv.transform(dict_test)

# %%
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=dv.feature_names_)
dtest = xgb.DMatrix(X_test, label=y_test, feature_names=dv.feature_names_)

xgb_params = {
'eta': 0.1,
'max_depth': 3,
'min_child_weight': 1,
'objective': 'binary:logistic',
'eval_metric': 'auc',
'nthread': 8,
'seed': 1,
'silent': 1
}

num_trees = 160
model = xgb.train(xgb_params, dtrain, num_boost_round=num_trees)
# Out:
# c:\Users\klmv0\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:51:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
y_pred_xgb = model.predict(dtest)
roc_auc_score(y_test, y_pred_xgb)
# Out:
# 0.8323212452959289
